# %%
import pandas as pd

data = pd.read_csv("pointsOfInteresting.csv")

# %%
data2 = data[["addr:city", "addr:housenumber", "addr:place", "addr:street", "geometry", "name", "type"] ]

# %%
data2
# Out:
#       addr:city addr:housenumber                               addr:place  \
# 0     Fortaleza              315                                      NaN
# 1           NaN              NaN                                      NaN
# 2           NaN              NaN                                      NaN
# 3           NaN              NaN                                      NaN
# 4           NaN              NaN                                      NaN
# 5           NaN              NaN                                      NaN
# 6           NaN              NaN                                      NaN
# 7           NaN              NaN                                      NaN
# 8           NaN              NaN                                      NaN
# 9           NaN              NaN                                      NaN
# 10          NaN              NaN                                      NaN
# 11          NaN              NaN                                      NaN
# ...

# %%
data.loc[0]
# Out:
# access                             NaN
# acess                              NaN
# addr:city                    Fortaleza
# addr:country                       NaN
# addr:housename                     NaN
# addr:housenumber                   315
# addr:place                         NaN
# addr:postcode                      NaN
# addr:state                         NaN
# addr:street         Rua Nestor Barbosa
# addr:suburb             Amadeu Furtado
# addr:unit                          NaN
# amenity                       hospital
# amenity_1                          NaN
# atm                                NaN
# barrier                            NaN
# bicycle                            NaN
# brand                              NaN
# brand:wikidata                     NaN
# brand:wikipedia                    NaN
# brewery                            NaN
# building:levels                    NaN
# bus                                NaN
# capacity                           NaN
# ...

# %%
# addr:place,,addr:suburb,addr:unit,amenity,amenity_1,atm,barrier,bicycle,brand,brand:wikidata,brand:wikipedia,brewery,building:levels,bus,capacity,cuisine,delivery,description,dispensing,drive_through,element_type,email,emergency,entrance,foot,geometry,healthcare,healthcare:speciality,highway,horse,internet_access,internet_access:fee,leisure,level,motor_vehicle,motorcar,motorcycle,name,name:en,name:pt,name:ru,natural,network,note,office,opening_hours,operator,operator:wikidata,operator:wikipedia,osmid,outdoor_seating,parking,payment:cash,payment:credit_cards,payment:debit_cards,phone,public_transport,religion,service:bicycle:repair,shop,short_name,smoking,sport,takeaway,traffic_calming,website,wheelchair,wifi,alt_name,building,building:colour,building:material,building:use,denomination,disused:amenity,fax,food,height,historic,indoor,internet_access:ssid,landuse,library,license_classes,lit,nodes,object,pedestrian,restaurant,roof:colour,roof:height,roof:levels,roof:material,roof:orientation,roof:shape,room,school,self_service,source,square,stars,start_date,surface,tipo,tourism,trailer,university,wikidata,wikipedia,type,ways,fixme,
